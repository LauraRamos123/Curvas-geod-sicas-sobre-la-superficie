# %%
# x''=0 

import numpy as np
import matplotlib.pyplot as plt
import math

n=10 #columnas
f=50 # filas

#x = np.zeros((f,n))
#x[:,0]=-5 # Condición inicial en la primera columna
#x[:,n-1]=10 # Condición inicial en la última columna

x = np.zeros(n)

x[0]=-5 # Condición inicial en la primera columna
x[n-1]=10 # Condición inicial en la última columna
#print(x)

for k in np.arange(1,f):
  for i in np.arange(1,n-1):
    x[i]=(x[i-1]+x[i+1])/2

#for k in np.arange(1,f):
#  for i in np.arange(1,n-1):
#    x[i]=(x[k-1,i-1]+x[k-1,i+1])/2    
  
plt.plot(x)
plt.title(r'$\frac{d^{2}f(x)}{dx^{2}}=0$')
plt.show()
  
#print(x)
#plt.plot(x[f-1,:])


#plt.plot(x[k,:])

# %%
import matplotlib.pyplot as plt


def sphere(r):
    u = np.linspace(0, 2 * np.pi, 200)
    v = np.linspace(0, np.pi, 200)
    d = (r) * np.outer(np.cos(u), np.sin(v))
    e = (r) * np.outer(np.sin(u), np.sin(v))
    f = (r) * np.outer(np.ones(np.size(u)), np.cos(v))
    return d,e,f

fig = plt.figure()
ax = fig.gca(projection='3d')    
d,e,f = sphere(1)
ax.plot_surface(d, e, f, rstride=3, cstride=3, color=(1,0.8,0,0.1))
